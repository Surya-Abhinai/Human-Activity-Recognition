# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/eda-of-human-activity-recognition/t-sne_perp_20_iter_1000.png
# /kaggle/input/eda-of-human-activity-recognition/t-sne_perp_5_iter_1000.png
# /kaggle/input/eda-of-human-activity-recognition/f_train.csv
# /kaggle/input/eda-of-human-activity-recognition/__results__.html
# /kaggle/input/eda-of-human-activity-recognition/t-sne_perp_10_iter_1000.png
# /kaggle/input/eda-of-human-activity-recognition/__resultx__.html
# /kaggle/input/eda-of-human-activity-recognition/__notebook__.ipynb
# /kaggle/input/eda-of-human-activity-recognition/__output__.json
# /kaggle/input/eda-of-human-activity-recognition/f_test.csv
# /kaggle/input/eda-of-human-activity-recognition/custom.css
# /kaggle/input/eda-of-human-activity-recognition/__results___files/__results___41_1.png
# /kaggle/input/eda-of-human-activity-recognition/__results___files/__results___56_7.png
# /kaggle/input/eda-of-human-activity-recognition/__results___files/__results___25_0.png
# ...

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/kaggle/input/eda-of-human-activity-recognition/f_train.csv")
data.iloc[:-1]
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0          0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1          0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2          0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3          0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4          0.276629      -0.016570      -0.115362     -0.998139     -0.980817
# ...             ...            ...            ...           ...           ...
# 7346       0.237966      -0.001088      -0.148326     -0.218949     -0.012927
# 7347       0.299665      -0.057193      -0.181233     -0.195387      0.039905
# 7348       0.273853      -0.007749      -0.147468     -0.235309      0.004816
# 7349       0.273387      -0.017011      -0.045022     -0.218218     -0.103822
# 7350       0.289654      -0.018843      -0.158281     -0.219139     -0.111412
#
# ...

# %%
print(data.columns)
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
print(data.Activity.unique())
# Out:
# ['STANDING' 'SITTING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS'
#  'WALKING_UPSTAIRS']

# %%
i = 0
for n in data.columns:
    print(i,n)
    i +=1
# Out:
# 0 tBodyAccmeanX
# 1 tBodyAccmeanY
# 2 tBodyAccmeanZ
# 3 tBodyAccstdX
# 4 tBodyAccstdY
# 5 tBodyAccstdZ
# 6 tBodyAccmadX
# 7 tBodyAccmadY
# 8 tBodyAccmadZ
# 9 tBodyAccmaxX
# 10 tBodyAccmaxY
# 11 tBodyAccmaxZ
# 12 tBodyAccminX
# 13 tBodyAccminY
# 14 tBodyAccminZ
# 15 tBodyAccsma
# 16 tBodyAccenergyX
# 17 tBodyAccenergyY
# 18 tBodyAccenergyZ
# 19 tBodyAcciqrX
# 20 tBodyAcciqrY
# 21 tBodyAcciqrZ
# 22 tBodyAccentropyX
# 23 tBodyAccentropyY
# 24 tBodyAccentropyZ
# 25 tBodyAccarCoeffX1
# 26 tBodyAccarCoeffX2
# 27 tBodyAccarCoeffX3
# 28 tBodyAccarCoeffX4
# 29 tBodyAccarCoeffY1
# 30 tBodyAccarCoeffY2
# 31 tBodyAccarCoeffY3
# 32 tBodyAccarCoeffY4
# 33 tBodyAccarCoeffZ1
# 34 tBodyAccarCoeffZ2
# 35 tBodyAccarCoeffZ3
# 36 tBodyAccarCoeffZ4
# 37 tBodyAcccorrelationXY
# 38 tBodyAcccorrelationXZ
# 39 tBodyAcccorrelationYZ
# 40 tGravityAccmeanX
# 41 tGravityAccmeanY
# 42 tGravityAccmeanZ
# 43 tGravityAccstdX
# 44 tGravityAccstdY
# 45 tGravityAccstdZ
# 46 tGravityAccmadX
# 47 tGravityAccmadY
# ...

# %%
sample = []
for i in range(7352):
    if data.iloc[i,561]==1 and data.iloc[i,562] == 'STANDING':
        x = pd.concat([data.iloc[i,:6],data.iloc[i,120:126]])
        sample.append(x)
        
sample_Standing = pd.DataFrame(sample)
sample_Standing
# Out:
#      tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0         0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1         0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2         0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3         0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4         0.276629      -0.016570      -0.115362     -0.998139     -0.980817
# 5         0.277199      -0.010098      -0.105137     -0.997335     -0.990487
# 6         0.279454      -0.019641      -0.110022     -0.996921     -0.967186
# 7         0.277432      -0.030488      -0.125360     -0.996559     -0.966728
# 8         0.277293      -0.021751      -0.120751     -0.997328     -0.961245
# 9         0.280586      -0.009960      -0.106065     -0.994803     -0.972758
# 10        0.276880      -0.012722      -0.103438     -0.994815     -0.973077
# ...

# %%
sample = []
for i in range(7352):
    if data.iloc[i,561]==1 and data.iloc[i,562] == 'SITTING':
        x = pd.concat([data.iloc[i,:6],data.iloc[i,120:126]])
        sample.append(x)
        
sample_Sitting = pd.DataFrame(sample)
sample_Sitting
# Out:
#      tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 27        0.144504       0.189263       0.062769     -0.904300     -0.181937
# 28        0.287252      -0.037455      -0.145974     -0.982915     -0.891605
# 29        0.279998      -0.019484      -0.105724     -0.992818     -0.940350
# 30        0.221847       0.034108      -0.123612     -0.814708     -0.749418
# 31       -0.041701       0.175102       0.025552     -0.758393     -0.586537
# 32        0.013904       0.153296       0.016243     -0.808638     -0.572746
# 33        0.303689      -0.004243      -0.150850     -0.956503     -0.838672
# 34        0.290760      -0.024035      -0.116739     -0.977374     -0.963841
# 35        0.270908      -0.014413      -0.106522     -0.993856     -0.993179
# 36        0.279553      -0.017001      -0.110517     -0.996076     -0.995782
# 37        0.276359      -0.016138      -0.108033     -0.995577     -0.994544
# ...

# %%
sample = []
for i in range(7352):
    if data.iloc[i,561]==1 and data.iloc[i,562] == 'LAYING':
        x = pd.concat([data.iloc[i,:6],data.iloc[i,120:126]])
        sample.append(x)
        
sample_Laying = pd.DataFrame(sample)
sample_Laying
# Out:
#      tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 51        0.403474      -0.015074      -0.118167     -0.914811     -0.895231
# 52        0.278373      -0.020561      -0.096825     -0.984883     -0.991118
# 53        0.276555      -0.017869      -0.107621     -0.994195     -0.996372
# 54        0.279575      -0.017276      -0.109481     -0.996135     -0.995812
# 55        0.276527      -0.016819      -0.107983     -0.996775     -0.997256
# 56        0.278123      -0.017146      -0.108014     -0.994928     -0.998359
# 57        0.278007      -0.017803      -0.108965     -0.994425     -0.994873
# 58        0.280206      -0.018396      -0.107489     -0.996475     -0.994069
# 59        0.281828      -0.018626      -0.105278     -0.996287     -0.992194
# 60        0.276729      -0.017210      -0.105638     -0.994788     -0.991031
# 61        0.275884      -0.016150      -0.108829     -0.995511     -0.995548
# ...

# %%
sample = []
for i in range(7352):
    if data.iloc[i,561]==1 and data.iloc[i,562] == 'WALKING':
        x = pd.concat([data.iloc[i,:6],data.iloc[i,120:126]])
        sample.append(x)
        
sample_Walking = pd.DataFrame(sample)
sample_Walking
# Out:
#      tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 78        0.282022      -0.037696      -0.134897     -0.328280     -0.137153
# 79        0.255841      -0.064550      -0.095186     -0.229207      0.016506
# 80        0.254867       0.003815      -0.123658     -0.275158      0.013080
# 81        0.343370      -0.014446      -0.167377     -0.229924      0.173911
# 82        0.276240      -0.029638      -0.142616     -0.226577      0.164288
# ..             ...            ...            ...           ...           ...
# 291       0.240809      -0.000509      -0.095618     -0.237635      0.156992
# 292       0.365629      -0.020383      -0.089326     -0.186608      0.194091
# 293       0.331172      -0.028691      -0.108391     -0.217812      0.208002
# 294       0.190223      -0.038897      -0.098696     -0.331107      0.044813
# 295       0.230039      -0.022025      -0.097876     -0.324575      0.051075
#
# ...

# %%
sample = []
for i in range(7352):
    if data.iloc[i,561]==1 and data.iloc[i,562] == 'WALKING_DOWNSTAIRS':
        x = pd.concat([data.iloc[i,:6],data.iloc[i,120:126]])
        sample.append(x)
        
sample_Walking_Downstairs = pd.DataFrame(sample)
sample_Walking_Downstairs
# Out:
#      tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 125       0.358455       0.017975      -0.084159     -0.171988     -0.188332
# 126       0.301715      -0.007049      -0.093681     -0.040143     -0.141421
# 127       0.281552      -0.016110      -0.140093     -0.094665     -0.007348
# 128       0.273956      -0.022899      -0.127256     -0.133382      0.132265
# 129       0.299957       0.014082      -0.082310      0.069268      0.057800
# 130       0.265374      -0.017156      -0.138773      0.120362      0.083344
# 131       0.277633      -0.037268      -0.100021     -0.021760     -0.032132
# 132       0.266880      -0.002307      -0.063727     -0.049966     -0.247403
# 133       0.210700      -0.005969      -0.109591     -0.064215     -0.202139
# 134       0.285213      -0.020202      -0.011024      0.122989      0.081946
# 135       0.469946      -0.033624      -0.141254      0.115463      0.019113
# ...

# %%
sample = []
for i in range(7352):
    if data.iloc[i,561]==1 and data.iloc[i,562] == 'WALKING_UPSTAIRS':
        x = pd.concat([data.iloc[i,:6],data.iloc[i,120:126]])
        sample.append(x)
        
sample_Walking_Upstairs = pd.DataFrame(sample)
sample_Walking_Upstairs
# Out:
#      tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 150       0.183604      -0.076559      -0.046956     -0.367516     -0.099161
# 151       0.279183      -0.036966      -0.133604     -0.359032     -0.124112
# 152       0.301162      -0.001759      -0.106830     -0.362666      0.001220
# 153       0.293411      -0.018715      -0.066159     -0.368157      0.095663
# 154       0.230310       0.002174      -0.043103     -0.335254     -0.020444
# 155       0.158517       0.004256      -0.018779     -0.406022     -0.083614
# 156       0.215245      -0.032628      -0.118966     -0.406744     -0.068915
# 157       0.271477      -0.030746      -0.156232     -0.341699     -0.152999
# 158       0.140859      -0.068262      -0.072116     -0.234499     -0.079449
# 159       0.231459      -0.013340      -0.092368     -0.316791     -0.114260
# 160       0.295693      -0.017291      -0.099928     -0.357120      0.041165
# ...

# %%
Standing_accmean = sample_Standing.iloc[:27,:3]
Standing_accmean.plot()
plt.title('Bar graph of Standing - Acceleration mean')
plt.show()
Standing_accstd = sample_Standing.iloc[:27,3:6]
Standing_accstd.plot()
plt.title('Bar graph of Standing - Acceleration std')
plt.show()
Standing_gyromean = sample_Standing.iloc[:27,6:9]
Standing_gyromean.plot()
plt.title('Bar graph of Standing - Gyro mean')
plt.show()
Standing_gyrostd = sample_Standing.iloc[:27,9:12]
Standing_gyrostd.plot()
plt.title('Bar graph of Standing - Gyro std')
plt.show()

# %%
Sitting_accmean = sample_Sitting.iloc[:24,:3]
Sitting_accmean.plot()
plt.title('Bar graph of Sitting - Acceleration mean')
plt.show()
Sitting_accstd = sample_Sitting.iloc[:24,3:6]
Sitting_accstd.plot()
plt.title('Bar graph of Sitting - Acceleration std')
plt.show()
Sitting_gyromean = sample_Sitting.iloc[:24,6:9]
Sitting_gyromean.plot()
plt.title('Bar graph of Sitting - Gyro mean')
plt.show()
Sitting_gyrostd = sample_Sitting.iloc[:24,9:12]
Sitting_gyrostd.plot()
plt.title('Bar graph of Sitting - Gyro std')
plt.show()

# %%
Laying_accmean = sample_Laying.iloc[:27,:3]
Laying_accmean.plot()
plt.title('Bar graph of Laying - Acceleration mean')
plt.show()
Laying_accstd = sample_Laying.iloc[:27,3:6]
Laying_accstd.plot()
plt.title('Bar graph of Laying - Acceleration std')
plt.show()
Laying_gyromean = sample_Laying.iloc[:27,6:9]
Laying_gyromean.plot()
plt.title('Bar graph of Laying - Gyro mean')
plt.show()
Laying_gyrostd = sample_Laying.iloc[:27,9:12]
Laying_gyrostd.plot()
plt.title('Bar graph of Laying - Gyro std')
plt.show()

# %%
Walking_accmean = sample_Walking.iloc[:26,:3]
Walking_accmean.plot()
plt.title('Bar graph of Walking - Acceleration mean')
plt.show()
Walking_accstd = sample_Walking.iloc[:26,3:6]
Walking_accstd.plot()
plt.title('Bar graph of Walking - Acceleration std')
plt.show()
Walking_gyromean = sample_Walking.iloc[:26,6:9]
Walking_gyromean.plot()
plt.title('Bar graph of Walking - Gyro mean')
plt.show()
Walking_gyrostd = sample_Walking.iloc[:26,9:12]
Walking_gyrostd.plot()
plt.title('Bar graph of Walking - Gyro std')
plt.show()

# %%
Walking_Downstair_accmean = sample_Walking_Downstairs.iloc[:25,:3]
Walking_Downstair_accmean.plot()
plt.title('Bar graph of Walking_Downstairs - Acceleration mean')
plt.show()
Walking_Downstair_accstd = sample_Walking_Downstairs.iloc[:25,3:6]
Walking_Downstair_accstd.plot()
plt.title('Bar graph of Walking_Downstairs - Acceleration std')
plt.show()
Walking_Downstair_gyromean = sample_Walking_Downstairs.iloc[:25,6:9]
Walking_Downstair_gyromean.plot()
plt.title('Bar graph of Walking_Downstairs - Gyro mean')
plt.show()
Walking_Downstair_gyrostd = sample_Walking_Downstairs.iloc[:25,9:12]
Walking_Downstair_gyrostd.plot()
plt.title('Bar graph of Walking_Downstairs - Gyro std')
plt.show()

# %%
Walking_Upstair_accmean = sample_Walking_Upstairs.iloc[:26,:3]
Walking_Upstair_accmean.plot()
plt.title('Bar graph of Walking_Upstairs - Acceleration mean')
plt.show()
Walking_Upstair_accstd = sample_Walking_Upstairs.iloc[:26,3:6]
Walking_Upstair_accstd.plot()
plt.title('Bar graph of Walking_Upstairs - Acceleration std')
plt.show()
Walking_Upstair_gyromean = sample_Walking_Upstairs.iloc[:26,6:9]
Walking_Upstair_gyromean.plot()
plt.title('Bar graph of Walking_Upstairs - Gyro mean')
plt.show()
Walking_Upstair_gyrostd = sample_Walking_Upstairs.iloc[:26,9:12]
Walking_Upstair_gyrostd.plot()
plt.title('Bar graph of Walking_Upstairs - Gyro std')
plt.show()
